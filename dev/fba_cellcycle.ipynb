# %%
import numpy as np
from tqdm import tqdm

from scipy.integrate import solve_ivp

import matplotlib.pyplot as plt
# %matplotlib inline

import cobra

# %%
cobra_config = cobra.Configuration()
# cobra_config.solver = "cplex"
ijr_model = cobra.io.read_sbml_model('/home/csiharath/Stage/iJR904.xml')
# model = cobra.io.read_sbml_model('/home/csiharath/Stage/HMRdatabase2_00.xml')

model.objective = 'biomass_components'
# Out:
# '[' is not a valid SBML 'SId'.
# 'M_10fthf[c]' is not a valid SBML 'SId'.
# 'M_12dgr_EC[c]' is not a valid SBML 'SId'.
# 'M_12ppd-S[c]' is not a valid SBML 'SId'.
# 'M_12ppd-S[e]' is not a valid SBML 'SId'.
# 'M_13dpg[c]' is not a valid SBML 'SId'.
# 'M_15dap[c]' is not a valid SBML 'SId'.
# 'M_15dap[e]' is not a valid SBML 'SId'.
# 'M_1pyr5c[c]' is not a valid SBML 'SId'.
# 'M_23ddhb[c]' is not a valid SBML 'SId'.
# 'M_23dhb[c]' is not a valid SBML 'SId'.
# 'M_23dhba[c]' is not a valid SBML 'SId'.
# 'M_23dhdp[c]' is not a valid SBML 'SId'.
# 'M_23dhmb[c]' is not a valid SBML 'SId'.
# 'M_23dhmp[c]' is not a valid SBML 'SId'.
# 'M_23doguln[c]' is not a valid SBML 'SId'.
# 'M_25aics[c]' is not a valid SBML 'SId'.
# 'M_25dkglcn[c]' is not a valid SBML 'SId'.
# 'M_25drapp[c]' is not a valid SBML 'SId'.
# 'M_26dap-LL[c]' is not a valid SBML 'SId'.
# 'M_26dap-M[c]' is not a valid SBML 'SId'.
# 'M_26dap-M[e]' is not a valid SBML 'SId'.
# 'M_2ahbut[c]' is not a valid SBML 'SId'.
# ...

# %%
G6P = "m01968c"
F6P = "m01845c"
GAP = "m01939c"
PEP = "m02696c"
PYR = "m02819c"
R5P = "m02845c"
X5P = "m01761c"
ACoA = "m01261c"
CIT = "m01587c"
AKG = "m01306c"
SUC = "m02943c"
MAL = "m02439c"
OXA = "m02633c"
LAC = "m01716c"
PALM = "m02674c"
GLU = "m01974c"
ALA = "m01638c"
NH4 = "m02579c"
GLCex = "m01965s"
ATP = "m01371c"
ADP = "m01285c"
AMP = "m01334c"
NAD = "m02552c"
NADH = "m02553c"
NADP = "m02554c"
NADHP = "m02555c"

# %%
# Modèle humain
# Param pour G1 :
# HK
model.reactions.get_by_id('HMR_4394').lower_bound = 10
model.reactions.get_by_id('HMR_4394').upper_bound = 1000
# PGI
model.reactions.get_by_id('HMR_4381').lower_bound = -1000
model.reactions.get_by_id('HMR_4381').upper_bound = 0
# PFK
model.reactions.get_by_id('HMR_4379').lower_bound = 0
model.reactions.get_by_id('HMR_4379').upper_bound = 1000
model.reactions.get_by_id('HMR_4375').lower_bound = -1000
model.reactions.get_by_id('HMR_4375').upper_bound = 0
model.reactions.get_by_id('HMR_4391').lower_bound = 0
model.reactions.get_by_id('HMR_4391').upper_bound = 1000
# PGK
model.reactions.get_by_id('HMR_4373').lower_bound = -1000
model.reactions.get_by_id('HMR_4373').upper_bound = 0
'''model.reactions.get_by_id('HMR_4368').lower_bound = 0
model.reactions.get_by_id('HMR_4368').upper_bound = 1000
model.reactions.get_by_id('HMR_4365').lower_bound = 0
model.reactions.get_by_id('HMR_4365').upper_bound = 1000'''
model.reactions.get_by_id('HMR_4363').lower_bound = 0
model.reactions.get_by_id('HMR_4363').upper_bound = 1000
# G6PDH
model.reactions.get_by_id('HMR_4304').lower_bound = 0
model.reactions.get_by_id('HMR_4304').upper_bound = 0
model.reactions.get_by_id('HMR_4623').lower_bound = 0
model.reactions.get_by_id('HMR_4623').upper_bound = 0
model.reactions.get_by_id('HMR_4474').lower_bound = 0
model.reactions.get_by_id('HMR_4474').upper_bound = 0
model.reactions.get_by_id('HMR_4352').lower_bound = 0
model.reactions.get_by_id('HMR_4352').upper_bound = 0
# AMP
# model.reactions.get_by_id('HMR_4052').lower_bound = 0
# model.reactions.get_by_id('HMR_4052').upper_bound = 0
# EP
model.reactions.get_by_id('HMR_4352').lower_bound = 0
model.reactions.get_by_id('HMR_4352').upper_bound = 0
model.reactions.get_by_id('HMR_4477').lower_bound = 0
model.reactions.get_by_id('HMR_4477').upper_bound = 0
# TKT
model.reactions.get_by_id('HMR_4501').lower_bound = 0
model.reactions.get_by_id('HMR_4501').upper_bound = 0
model.reactions.get_by_id('HMR_4565').lower_bound = 0
model.reactions.get_by_id('HMR_4565').upper_bound = 0
# Citrate liase 
model.reactions.get_by_id('HMR_4149').lower_bound = 0
model.reactions.get_by_id('HMR_4149').upper_bound = 0
# Palmitate
model.reactions.get_by_id('HMR_0709').lower_bound = 0
model.reactions.get_by_id('HMR_0709').upper_bound = 0

solution = model.optimize()
# print(solution.objective_value)
# print(solution.status)
# print(solution.shadow_prices)
# model.summary()
s = solution.fluxes
dict_fluxes = s.to_frame().to_dict()['fluxes']
dict_fluxes1 = {x:y for x,y in dict_fluxes.items() if y!=0}

# G1
print(f"hk :{dict_fluxes['HMR_4394']}")
print(f"pgi :{dict_fluxes['HMR_4381']}") # neg
print(f"pfk :{dict_fluxes['HMR_4379']};{dict_fluxes['HMR_4375']};{dict_fluxes['HMR_4391']}") #2neg
print(f"pgk :{dict_fluxes['HMR_4373']};{dict_fluxes['HMR_4368']};{dict_fluxes['HMR_4365']};{dict_fluxes['HMR_4363']}") # 1neg
print(f"pk :{dict_fluxes['HMR_4421']}\n")

# S
print(f"g6pdh :{dict_fluxes['HMR_4304']};{dict_fluxes['HMR_4623']};{dict_fluxes['HMR_4474']};{dict_fluxes['HMR_4352']}") #4 neg
print(f"ep :{dict_fluxes['HMR_4352']};{dict_fluxes['HMR_4477']}")
print(f"amp :{dict_fluxes['HMR_4052']}")
print(f"tkt1 :{dict_fluxes['HMR_4501']}")
print(f"tkt2 :{dict_fluxes['HMR_4565']}\n")

# TCA cycle
# print(f"pdh :{dict_fluxes['PDH']}")
print(f"cs :{dict_fluxes['HMR_4145']}")
print(f"cits :{dict_fluxes['HMR_4586']}")
print(f"AKGDH :{dict_fluxes['HMR_4152']}\n")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# Lactate
print(f"ldh :{dict_fluxes['HMR_4388']}\n")
# G2
print(f"acl :{dict_fluxes['HMR_4149']}")
print(f"palm :{dict_fluxes['HMR_0709']}")
# print(f" :{dict_fluxes['']}")

r = model.reactions.get_by_id("HMR_4373")
# Out:
# hk :10.0
# pgi :-205.6620012479343
# pfk :0.0;0.0;0.0
# pgk :0.0;0.0;-720.484448256072;720.484448256072
# pk :182.2764356648683
#
# g6pdh :0.0;0.0;0.0;0.0
# ep :0.0;0.0
# amp :0.0
# tkt1 :0.0
# tkt2 :0.0
#
# cs :887.944217613245
# cits :0.0
# AKGDH :0.0
#
# ldh :0.0
#
# acl :0.0
# palm :0.0

# %%
#faire une liste
for r in model.reactions:
    if m in r.reactants:
        print(r)
    elif r.reversible and m in r.products:
        print(r)

# %%
r.summary(solution = solution)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HMR_4373'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
help(r)
# Out:
# Help on Reaction in module cobra.core.reaction object:
#
# class Reaction(cobra.core.object.Object)
#  |  Reaction(id=None, name='', subsystem='', lower_bound=0.0, upper_bound=None)
#  |
#  |  Reaction is a class for holding information regarding
#  |  a biochemical reaction in a cobra.Model object.
#  |
#  |  Reactions are by default irreversible with bounds
#  |  `(0.0, cobra.Configuration().upper_bound)`
#  |  if no bounds are provided on creation.
#  |  To create an irreversible reaction use `lower_bound=None`,
#  |  resulting in reaction bounds of
#  |  `(cobra.Configuration().lower_bound, cobra.Configuration().upper_bound)`.
#  |
#  |  Parameters
#  |  ----------
#  |  id : string
#  |      The identifier to associate with this reaction
#  |  name : string
#  |      A human readable name for the reaction
#  |  subsystem : string
#  |      Subsystem where the reaction is meant to occur
#  |  lower_bound : float
#  |      The lower flux bound
#  |  upper_bound : float
# ...

# %%
# Modèle humain
# Param pour S :
# HK
model.reactions.get_by_id('HMR_4394').lower_bound = 10
model.reactions.get_by_id('HMR_4394').upper_bound = 1000
#PGI
model.reactions.get_by_id('HMR_4381').lower_bound = 0
model.reactions.get_by_id('HMR_4381').upper_bound = 0
# PFK
model.reactions.get_by_id('HMR_4379').lower_bound = 0
model.reactions.get_by_id('HMR_4379').upper_bound = 0
model.reactions.get_by_id('HMR_4375').lower_bound = 0
model.reactions.get_by_id('HMR_4375').upper_bound = 0
model.reactions.get_by_id('HMR_4391').lower_bound = 0
model.reactions.get_by_id('HMR_4391').upper_bound = 0
# PGK
model.reactions.get_by_id('HMR_4373').lower_bound = 0
model.reactions.get_by_id('HMR_4373').upper_bound = 0
'''model.reactions.get_by_id('HMR_4368').lower_bound = 0
model.reactions.get_by_id('HMR_4368').upper_bound = 0
model.reactions.get_by_id('HMR_4365').lower_bound = 0
model.reactions.get_by_id('HMR_4365').upper_bound = 0'''
model.reactions.get_by_id('HMR_4363').lower_bound = 0
model.reactions.get_by_id('HMR_4363').upper_bound = 0
# G6PDH
model.reactions.get_by_id('HMR_4304').lower_bound = 1000
model.reactions.get_by_id('HMR_4304').upper_bound = 1000
model.reactions.get_by_id('HMR_4623').lower_bound = 0
model.reactions.get_by_id('HMR_4623').upper_bound = 1000
model.reactions.get_by_id('HMR_4474').lower_bound = 0
model.reactions.get_by_id('HMR_4474').upper_bound = 1000
model.reactions.get_by_id('HMR_4352').lower_bound = -1000
model.reactions.get_by_id('HMR_4352').upper_bound = 0
# AMP
model.reactions.get_by_id('HMR_4052').lower_bound = 0
model.reactions.get_by_id('HMR_4052').upper_bound = 1000
# EP
model.reactions.get_by_id('HMR_4352').lower_bound = 0
model.reactions.get_by_id('HMR_4352').upper_bound = 1000
model.reactions.get_by_id('HMR_4477').lower_bound = -1000
model.reactions.get_by_id('HMR_4477').upper_bound = 0
# TKT
model.reactions.get_by_id('HMR_4501').lower_bound = 0
model.reactions.get_by_id('HMR_4501').upper_bound = 1000
model.reactions.get_by_id('HMR_4565').lower_bound = 0
model.reactions.get_by_id('HMR_4565').upper_bound = 1000
# Citrate liase 
model.reactions.get_by_id('HMR_4149').lower_bound = 0
model.reactions.get_by_id('HMR_4149').upper_bound = 0
# Palmitate
model.reactions.get_by_id('HMR_0709').lower_bound = 0
model.reactions.get_by_id('HMR_0709').upper_bound = 0

solution = model.optimize()
# print(solution.objective_value)
# print(solution.status)
# print(solution.shadow_prices)
# model.summary()
s = solution.fluxes
dict_fluxes = s.to_frame().to_dict()['fluxes']
dict_fluxes1 = {x:y for x,y in dict_fluxes.items() if y!=0}

# G1
print(f"hk :{dict_fluxes['HMR_4394']}")
print(f"pgi :{dict_fluxes['HMR_4381']}") # neg
print(f"pfk :{dict_fluxes['HMR_4379']};{dict_fluxes['HMR_4375']};{dict_fluxes['HMR_4391']}") #2neg
print(f"pgk :{dict_fluxes['HMR_4373']};{dict_fluxes['HMR_4368']};{dict_fluxes['HMR_4365']};{dict_fluxes['HMR_4363']}") # 1neg
print(f"pk :{dict_fluxes['HMR_4421']}\n")

# S
print(f"g6pdh :{dict_fluxes['HMR_4304']};{dict_fluxes['HMR_4623']};{dict_fluxes['HMR_4474']};{dict_fluxes['HMR_4352']}") #4 neg
print(f"ep :{dict_fluxes['HMR_4352']};{dict_fluxes['HMR_4477']}")
print(f"amp :{dict_fluxes['HMR_4052']}")
print(f"tkt1 :{dict_fluxes['HMR_4501']}")
print(f"tkt2 :{dict_fluxes['HMR_4565']}\n")

# TCA cycle
# print(f"pdh :{dict_fluxes['PDH']}")
print(f"cs :{dict_fluxes['HMR_4145']}")
print(f"cits :{dict_fluxes['HMR_4586']}")
print(f"AKGDH :{dict_fluxes['HMR_4152']}\n")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# Lactate
print(f"ldh :{dict_fluxes['HMR_4388']}\n")
# G2
print(f"acl :{dict_fluxes['HMR_4149']}")
print(f"palm :{dict_fluxes['HMR_0709']}")
# print(f" :{dict_fluxes['']}")
# Out:
# hk :10.0
# pgi :0.0
# pfk :0.0;0.0;0.0
# pgk :0.0;0.0;0.0;0.0
# pk :0.0
#
# g6pdh :1000.0;0.0;0.0;0.0
# ep :0.0;0.0
# amp :0.0
# tkt1 :0.0
# tkt2 :0.0
#
# cs :-32.79817217163236
# cits :0.0
# AKGDH :438.4023211498485
#
# ldh :0.0
#
# acl :0.0
# palm :0.0

# %% [raw]
# Results for S:
# hk :10.0
# pgi :0.0
# pfk :0.0;0.0;0.0
# pgk :0.0;0.0;0.0;0.0
# pk :0.0
#
# g6pdh :1000.0;674.9113480827089;0.0;0.0
# ep :0.0;0.0
# amp :383.37717127897076
# tkt1 :0.0
# tkt2 :0.0
#
# cs :0.0
# cits :0.0
# AKGDH :528.8386768687717
#
# ldh :0.0
#
# acl :0.0
# palm :0.0

# %%
# Modèle humain
# Param pour G2:
# HK
model.reactions.get_by_id('HMR_4394').lower_bound = 10
model.reactions.get_by_id('HMR_4394').upper_bound = 1000
#PGI
model.reactions.get_by_id('HMR_4381').lower_bound = 0
model.reactions.get_by_id('HMR_4381').upper_bound = 0
# PFK
model.reactions.get_by_id('HMR_4379').lower_bound = 0
model.reactions.get_by_id('HMR_4379').upper_bound = 0
model.reactions.get_by_id('HMR_4375').lower_bound = 0
model.reactions.get_by_id('HMR_4375').upper_bound = 0
model.reactions.get_by_id('HMR_4391').lower_bound = 0
model.reactions.get_by_id('HMR_4391').upper_bound = 0
# PGK
model.reactions.get_by_id('HMR_4373').lower_bound = 0
model.reactions.get_by_id('HMR_4373').upper_bound = 0
'''model.reactions.get_by_id('HMR_4368').lower_bound = 0
model.reactions.get_by_id('HMR_4368').upper_bound = 0
model.reactions.get_by_id('HMR_4365').lower_bound = 0
model.reactions.get_by_id('HMR_4365').upper_bound = 0'''
model.reactions.get_by_id('HMR_4363').lower_bound = 0
model.reactions.get_by_id('HMR_4363').upper_bound = 0
# G6PDH
model.reactions.get_by_id('HMR_4304').lower_bound = 1000
model.reactions.get_by_id('HMR_4304').upper_bound = 1000
model.reactions.get_by_id('HMR_4623').lower_bound = 0
model.reactions.get_by_id('HMR_4623').upper_bound = 1000
model.reactions.get_by_id('HMR_4474').lower_bound = 0
model.reactions.get_by_id('HMR_4474').upper_bound = 1000
model.reactions.get_by_id('HMR_4352').lower_bound = -1000
model.reactions.get_by_id('HMR_4352').upper_bound = 0
# AMP
model.reactions.get_by_id('HMR_4052').lower_bound = 0
model.reactions.get_by_id('HMR_4052').upper_bound = 1000
# EP
model.reactions.get_by_id('HMR_4352').lower_bound = 0
model.reactions.get_by_id('HMR_4352').upper_bound = 1000
model.reactions.get_by_id('HMR_4477').lower_bound = -1000
model.reactions.get_by_id('HMR_4477').upper_bound = 0
# TKT
model.reactions.get_by_id('HMR_4501').lower_bound = 0
model.reactions.get_by_id('HMR_4501').upper_bound = 1000
model.reactions.get_by_id('HMR_4565').lower_bound = 0
model.reactions.get_by_id('HMR_4565').upper_bound = 1000
# Citrate liase 
model.reactions.get_by_id('HMR_4149').lower_bound = 0
model.reactions.get_by_id('HMR_4149').upper_bound = 1000
# Palmitate
model.reactions.get_by_id('HMR_0709').lower_bound = 0
model.reactions.get_by_id('HMR_0709').upper_bound = 1000

solution = model.optimize()
# print(solution.objective_value)
# print(solution.status)
# print(solution.shadow_prices)
# model.summary()
s = solution.fluxes
dict_fluxes = s.to_frame().to_dict()['fluxes']
dict_fluxes1 = {x:y for x,y in dict_fluxes.items() if y!=0}

# G1
print(f"hk :{dict_fluxes['HMR_4394']}")
print(f"pgi :{dict_fluxes['HMR_4381']}") # neg
print(f"pfk :{dict_fluxes['HMR_4379']};{dict_fluxes['HMR_4375']};{dict_fluxes['HMR_4391']}") #2neg
print(f"pgk :{dict_fluxes['HMR_4373']};{dict_fluxes['HMR_4368']};{dict_fluxes['HMR_4365']};{dict_fluxes['HMR_4363']}") # 1neg
print(f"pk :{dict_fluxes['HMR_4421']}\n")

# S
print(f"g6pdh :{dict_fluxes['HMR_4304']};{dict_fluxes['HMR_4623']};{dict_fluxes['HMR_4474']};{dict_fluxes['HMR_4352']}") #4 neg
print(f"ep :{dict_fluxes['HMR_4352']};{dict_fluxes['HMR_4477']}")
print(f"amp :{dict_fluxes['HMR_4052']}")
print(f"tkt1 :{dict_fluxes['HMR_4501']}")
print(f"tkt2 :{dict_fluxes['HMR_4565']}\n")

# TCA cycle
# print(f"pdh :{dict_fluxes['PDH']}")
print(f"cs :{dict_fluxes['HMR_4145']}")
print(f"cits :{dict_fluxes['HMR_4586']}")
print(f"AKGDH :{dict_fluxes['HMR_4152']}\n")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# Lactate
print(f"ldh :{dict_fluxes['HMR_4388']}\n")
# G2
print(f"acl :{dict_fluxes['HMR_4149']}")
print(f"palm :{dict_fluxes['HMR_0709']}")
# print(f" :{dict_fluxes['']}")
# Out:
# hk :10.0
# pgi :0.0
# pfk :0.0;0.0;0.0
# pgk :0.0;0.0;0.0;0.0
# pk :0.0
#
# g6pdh :1000.0;674.9113480827089;0.0;0.0
# ep :0.0;0.0
# amp :383.37717127897076
# tkt1 :0.0
# tkt2 :0.0
#
# cs :0.0
# cits :0.0
# AKGDH :528.8386768687717
#
# ldh :0.0
#
# acl :0.0
# palm :0.0

# %%
solution = model.optimize()
# print(solution.objective_value)
# print(solution.status)
# print(solution.shadow_prices)
# model.summary()
s = solution.fluxes
dict_fluxes = s.to_frame().to_dict()['fluxes']
dict_fluxes1 = {x:y for x,y in dict_fluxes.items() if y!=0}

# G1
print(f"hk :{dict_fluxes['HMR_4394']}")
print(f"pgi :{dict_fluxes['HMR_4381']}") # neg
print(f"pfk :{dict_fluxes['HMR_4379']};{dict_fluxes['HMR_4375']};{dict_fluxes['HMR_4391']}") #2neg
print(f"pgk :{dict_fluxes['HMR_4373']};{dict_fluxes['HMR_4368']};{dict_fluxes['HMR_4365']};{dict_fluxes['HMR_4363']}") # 1neg
print(f"pk :{dict_fluxes['HMR_4421']}\n")

# S
print(f"g6pdh :{dict_fluxes['HMR_4304']};{dict_fluxes['HMR_4623']};{dict_fluxes['HMR_4474']};{dict_fluxes['HMR_4352']}") #4 neg
print(f"ep :{dict_fluxes['HMR_4352']};{dict_fluxes['HMR_4477']}")
print(f"amp :{dict_fluxes['HMR_4052']}")
print(f"tkt1 :{dict_fluxes['HMR_4501']}")
print(f"tkt2 :{dict_fluxes['HMR_4565']}\n")

# TCA cycle
# print(f"pdh :{dict_fluxes['PDH']}")
print(f"cs :{dict_fluxes['HMR_4145']}")
print(f"cits :{dict_fluxes['HMR_4586']}")
print(f"AKGDH :{dict_fluxes['HMR_4152']}\n")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# Lactate
print(f"ldh :{dict_fluxes['HMR_4388']}\n")
# G2
print(f"acl :{dict_fluxes['HMR_4149']}")
print(f"palm :{dict_fluxes['HMR_0709']}")
# print(f" :{dict_fluxes['']}")
# Out:
# hk :10.0
# pgi :-205.6620012479343
# pfk :0.0;0.0;0.0
# pgk :0.0;0.0;-720.484448256072;720.484448256072
# pk :182.2764356648683
#
# g6pdh :0.0;0.0;0.0;0.0
# ep :0.0;0.0
# amp :0.0
# tkt1 :0.0
# tkt2 :0.0
#
# cs :887.944217613245
# cits :0.0
# AKGDH :0.0
#
# ldh :0.0
#
# acl :0.0
# palm :0.0

# %%
# Modéle e.coli
# Param pour G1 :
model.reactions.get_by_id('PFK').lower_bound = -1000
model.reactions.get_by_id('PFK').upper_bound = 1000
# print(model.reactions.get_by_id('PFK').bounds)
# FB3? 
model.reactions.get_by_id('G6PDH2r').lower_bound = 0
model.reactions.get_by_id('G6PDH2r').upper_bound = 0
model.reactions.get_by_id('TKT1').lower_bound = 0
model.reactions.get_by_id('TKT1').upper_bound = 0
# model.reactions.get_by_id('TKT2').lower_bound = 0
# model.reactions.get_by_id('TKT2').upper_bound = 0
# enzyme lipidique 
model.reactions.get_by_id('CITL').lower_bound = 0
model.reactions.get_by_id('CITL').upper_bound = 0

solution = model.optimize()
# print(solution.objective_value)
# print(solution.status)
# print(solution.shadow_prices)
# model.summary()
s = solution.fluxes
dict_fluxes = s.to_frame().to_dict()['fluxes']
dict_fluxes1 = {x:y for x,y in dict_fluxes.items() if y!=0}

# G1
print(f"hk :{dict_fluxes['HEX1']}")
print(f"pgi :{dict_fluxes['PGI']}")
print(f"pfk :{dict_fluxes['PFK']}")
print(f"pgk :{dict_fluxes['PGK']}")
print(f"pk :{dict_fluxes['PYK']}\n")
# S
print(f"g6pdh :{dict_fluxes['G6PDH2r']}")
print(f"ep :{dict_fluxes['RPE']}")
print(f"tkt1 :{dict_fluxes['TKT1']}")
print(f"tkt2 :{dict_fluxes['TKT2']}\n")
# TCA cycle
print(f"pdh :{dict_fluxes['PDH']}")
print(f"cs :{dict_fluxes['CS']}")
print(f"cits :{dict_fluxes['ICDHyr']}")
print(f"AKGDH :{dict_fluxes['AKGDH']}\n")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# Lactate
print(f"ldh :{dict_fluxes['LDH_D']}\n")
# G2
print(f"acl :{dict_fluxes['CITL']}")
# print(f" :{dict_fluxes['']}")
# Out:
# hk :0.0
# pgi :9.165992563480938
# pfk :5.70663756141766
# pgk :-17.094005296478592
# pk :0.0
#
# g6pdh :0.0
# ep :-0.38990730580103294
# tkt1 :0.0
# tkt2 :-0.38990730580103294
#
# pdh :9.922170807624891
# cs :6.537883154520651
# cits :6.537883154520651
# AKGDH :5.545148047178544
#
# ldh :0.0
#
# acl :0.0

# %%
# Modéle e.coli
# Param pour S :
model.reactions.get_by_id('PFK').lower_bound = 0
model.reactions.get_by_id('PFK').upper_bound = 0
model.reactions.get_by_id('PGI').lower_bound = 0
model.reactions.get_by_id('PGI').upper_bound = 0
# print(model.reactions.get_by_id('PFK').bounds)
# FB3? 
model.reactions.get_by_id('G6PDH2r').lower_bound = -1000
model.reactions.get_by_id('G6PDH2r').upper_bound = 1000
# model.reactions.get_by_id('TKT1').lower_bound = 0
# model.reactions.get_by_id('TKT1').upper_bound = 0
# model.reactions.get_by_id('TKT2').lower_bound = 0
# model.reactions.get_by_id('TKT2').upper_bound = 0
# enzyme lipidique 
model.reactions.get_by_id('CITL').lower_bound = 0
model.reactions.get_by_id('CITL').upper_bound = 0

solution = model.optimize()
# print(solution.objective_value)
# print(solution.status)
# print(solution.shadow_prices)
# model.summary()
s = solution.fluxes
dict_fluxes = s.to_frame().to_dict()['fluxes']
dict_fluxes1 = {x:y for x,y in dict_fluxes.items() if y!=0}

# G1
print(f"hk :{dict_fluxes['HEX1']}")
print(f"pgi :{dict_fluxes['PGI']}")
print(f"pfk :{dict_fluxes['PFK']}")
print(f"pgk :{dict_fluxes['PGK']}")
print(f"pk :{dict_fluxes['PYK']}\n")
# S
print(f"g6pdh :{dict_fluxes['G6PDH2r']}")
print(f"ep :{dict_fluxes['RPE']}")
print(f"tkt1 :{dict_fluxes['TKT1']}")
print(f"tkt2 :{dict_fluxes['TKT2']}\n")
# TCA cycle
print(f"pdh :{dict_fluxes['PDH']}")
print(f"cs :{dict_fluxes['CS']}")
print(f"cits :{dict_fluxes['ICDHyr']}")
print(f"AKGDH :{dict_fluxes['AKGDH']}\n")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# Lactate
print(f"ldh :{dict_fluxes['LDH_D']}\n")
# G2
print(f"acl :{dict_fluxes['CITL']}")
# print(f" :{dict_fluxes['']}")
# Out:
# hk :4.446394044418078
# pgi :0.0
# pfk :0.0
# pgk :-8.070163279014068
# pk :0.0
#
# g6pdh :9.855303186465788
# ep :-0.363157365153183
# tkt1 :0.0
# tkt2 :-0.363157365153183
#
# pdh :12.300111424030504
# cs :5.819109527959965
# cits :3.874201193536697
# AKGDH :2.949573569192073
#
# ldh :0.0
#
# acl :0.0

# %%
# Modéle e.coli
# Param pour G2 :
model.reactions.get_by_id('PFK').lower_bound = 0
model.reactions.get_by_id('PFK').upper_bound = 0
# model.reactions.get_by_id('PGI').lower_bound = 0
# model.reactions.get_by_id('PGI').upper_bound = 0
# print(model.reactions.get_by_id('PFK').bounds)
# FB3? 
model.reactions.get_by_id('G6PDH2r').lower_bound = -1000
model.reactions.get_by_id('G6PDH2r').upper_bound = 1000
model.reactions.get_by_id('TKT1').lower_bound = - 1000
model.reactions.get_by_id('TKT1').upper_bound = 1000
# model.reactions.get_by_id('TKT2').lower_bound = 0
# model.reactions.get_by_id('TKT2').upper_bound = 0
# enzyme lipidique 
model.reactions.get_by_id('CITL').lower_bound = 0
model.reactions.get_by_id('CITL').upper_bound = 1000

solution = model.optimize()
# print(solution.objective_value)
# print(solution.status)
# print(solution.shadow_prices)
# model.summary()
s = solution.fluxes
dict_fluxes = s.to_frame().to_dict()['fluxes']
dict_fluxes1 = {x:y for x,y in dict_fluxes.items() if y!=0}

# G1
print(f"hk :{dict_fluxes['HEX1']}")
print(f"pgi :{dict_fluxes['PGI']}")
print(f"pfk :{dict_fluxes['PFK']}")
print(f"pgk :{dict_fluxes['PGK']}")
print(f"pk :{dict_fluxes['PYK']}\n")
# S
print(f"g6pdh :{dict_fluxes['G6PDH2r']}")
print(f"ep :{dict_fluxes['RPE']}")
print(f"tkt1 :{dict_fluxes['TKT1']}")
print(f"tkt2 :{dict_fluxes['TKT2']}\n")
# TCA cycle
print(f"pdh :{dict_fluxes['PDH']}")
print(f"cs :{dict_fluxes['CS']}")
print(f"cits :{dict_fluxes['ICDHyr']}")
print(f"AKGDH :{dict_fluxes['AKGDH']}\n")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# Lactate
print(f"ldh :{dict_fluxes['LDH_D']}\n")
# G2
print(f"acl :{dict_fluxes['CITL']}")
# print(f" :{dict_fluxes['']}")
# Out:
# hk :4.36639111743491
# pgi :3.6046959002818673
# pfk :0.0
# pgk :-15.009963423582416
# pk :0.0
#
# g6pdh :6.237444662779701
# ep :3.114462874145997
# tkt1 :1.7553277730699612
# tkt2 :1.359135101076036
#
# pdh :9.844348505884016
# cs :4.593128223506877
# cits :2.471297568982263
# AKGDH :1.4625594178670553
#
# ldh :0.0
#
# acl :0.0

# %%
# Modèle humain
# Param pour G1 :
model.reactions.get_by_id('HMR_4394').upper_bound = 1000
model.reactions.get_by_id('HMR_4381').upper_bound = 1000
# PFK
model.reactions.get_by_id('HMR_4379').lower_bound = -1000
model.reactions.get_by_id('HMR_4379').upper_bound = 1000
model.reactions.get_by_id('HMR_4375').lower_bound = -1000
model.reactions.get_by_id('HMR_4375').upper_bound = 1000
model.reactions.get_by_id('HMR_4391').lower_bound = -1000
model.reactions.get_by_id('HMR_4391').upper_bound = 1000
# G6PDH
model.reactions.get_by_id('HMR_4304').lower_bound = 0
model.reactions.get_by_id('HMR_4304').upper_bound = 0
model.reactions.get_by_id('HMR_4352').lower_bound = 0
model.reactions.get_by_id('HMR_4352').upper_bound = 0
# TKT
model.reactions.get_by_id('HMR_4565').lower_bound = 0
model.reactions.get_by_id('HMR_4565').upper_bound = 0
# Citrate liase 
model.reactions.get_by_id('HMR_4149').lower_bound = 0
model.reactions.get_by_id('HMR_4149').upper_bound = 0
# Palmitate
model.reactions.get_by_id('HMR_0709').lower_bound = 0
model.reactions.get_by_id('HMR_0709').upper_bound = 0

solution = model.optimize()
# print(solution.objective_value)
# print(solution.status)
# print(solution.shadow_prices)
# model.summary()
s = solution.fluxes
dict_fluxes = s.to_frame().to_dict()['fluxes']
dict_fluxes1 = {x:y for x,y in dict_fluxes.items() if y!=0}

# G1
print(f"hk :{dict_fluxes['HMR_4394']}")
print(f"pgi :{dict_fluxes['HMR_4381']}")
print(f"pfk :{dict_fluxes['HMR_4379']};{dict_fluxes['HMR_4391']}")
print(f"pgk :{dict_fluxes['HMR_4373']};{dict_fluxes['HMR_4363']}")
print(f"pk :{dict_fluxes['HMR_4421']}\n")

# S
print(f"g6pdh :{dict_fluxes['G6PDH2r']}")
print(f"ep :{dict_fluxes['RPE']}")
print(f"tkt1 :{dict_fluxes['TKT1']}")
print(f"tkt2 :{dict_fluxes['TKT2']}\n")

# TCA cycle
print(f"pdh :{dict_fluxes['PDH']}")
print(f"cs :{dict_fluxes['CS']}")
print(f"cits :{dict_fluxes['ICDHyr']}")
print(f"AKGDH :{dict_fluxes['AKGDH']}\n")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# print(f" :{dict_fluxes['']}")
# Lactate
print(f"ldh :{dict_fluxes['LDH_D']}\n")
# G2
print(f"acl :{dict_fluxes['CITL']}")
print(f"palm :{dict_fluxes['ARTPLM1m']}")
# print(f" :{dict_fluxes['']}")
# Out:
# hk :1000.0
# pgi :-1000.0
# pfk :0.0;261.5658316046082
# pgk :0.0;0.0
# pk :0.0

# %%
solution = model.optimize()
print(model.objective)
# Out:
# Maximize
# 1.0*biomass_components - 1.0*biomass_components_reverse_c1825

# %%
# HMR_4373(-)
r = model.reactions.get_by_id('R_HMR_4373')
r.summary()
# Out:
# /home/csiharath/.local/lib/python3.8/site-packages/cobra/core/dictlist.py:214: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if current_length is 0:
# /home/csiharath/.local/lib/python3.8/site-packages/cobra/core/dictlist.py:214: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if current_length is 0:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [158], in <cell line: 2>()
#       1 # HMR_4373(-)
# ----> 2 r = model.reactions.get_by_id('R_HMR_4373')
#       3 r.summary()
#
# File ~/.local/lib/python3.8/site-packages/cobra/core/dictlist.py:57, in DictList.get_by_id(self, id)
#      55 def get_by_id(self, id):
#      56     """return the element with a matching id"""
# ---> 57     return list.__getitem__(self, self._dict[id])
#
# KeyError: 'R_HMR_4373'

# %%
#HMR_4368

# %%
#HMR_4365

# %%
#HMR_4363
