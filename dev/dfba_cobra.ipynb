# %%
import numpy as np
from tqdm import tqdm

from scipy.integrate import solve_ivp

import matplotlib.pyplot as plt
# %matplotlib inline

import cobra
import time

# %%
model_HMR = cobra.io.read_sbml_model('/home/csiharath/Stage/HMRdatabase2_00.xml')
# Out:
# Model does not contain SBML fbc package information.
# SBML package 'layout' not supported by cobrapy, information is not parsed
# SBML package 'render' not supported by cobrapy, information is not parsed
# urn:miriam:9606 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# urn:miriam:obo.chebi:CHEBI:15389 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_m00001c "(-)-trans-carveol">
# urn:miriam:obo.chebi:CHEBI:15389 does not conform to 'http(s)://identifiers.org/collection/id' or'http(s)://identifiers.org/COLLECTION:id
# Use of FORMULA in the notes element is discouraged, use fbc:chemicalFormula instead: <Species M_m00001s "(-)-trans-carveol">
# ...

# %%
model_HMR.objective = 'biomass_components'

# %%
def add_dynamic_bounds(model, y):
    """Use external concentrations to bound the uptake flux of glucose."""
    biomass, glucose = y  # expand the boundary species
    glucose_max_import = -10 * glucose / (5 + glucose)
    model.reactions.EX_m01965x.lower_bound = glucose_max_import


def dynamic_system(t, y):
    """Calculate the time derivative of external species."""

    biomass, glucose = y  # expand the boundary species

    # Calculate the specific exchanges fluxes at the given external concentrations.
    with model_HMR:
        add_dynamic_bounds(model_HMR, y)

        cobra.util.add_lp_feasibility(model_HMR)
        feasibility = cobra.util.fix_objective_as_constraint(model_HMR)
        lex_constraints = cobra.util.add_lexicographic_constraints(
            model_HMR, ['biomass_components', 'EX_m01965x'], ['max', 'max'])

    # Since the calculated fluxes are specific rates, we multiply them by the
    # biomass concentration to get the bulk exchange rates.
    fluxes = lex_constraints.values
    fluxes *= biomass

    # This implementation is **not** efficient, so I display the current
    # simulation time using a progress bar.
    if dynamic_system.pbar is not None:
        dynamic_system.pbar.update(1)
        dynamic_system.pbar.set_description('t = {:.3f}'.format(t))

    return fluxes

dynamic_system.pbar = None


def infeasible_event(t, y):
    """
    Determine solution feasibility.

    Avoiding infeasible solutions is handled by solve_ivp's built-in event detection.
    This function re-solves the LP to determine whether or not the solution is feasible
    (and if not, how far it is from feasibility). When the sign of this function changes
    from -epsilon to positive, we know the solution is no longer feasible.

    """

    with model_HMR:

        add_dynamic_bounds(model_HMR, y)

        cobra.util.add_lp_feasibility(model_HMR)
        feasibility = cobra.util.fix_objective_as_constraint(model_HMR)

    return feasibility - infeasible_event.epsilon

infeasible_event.epsilon = 1E-6
infeasible_event.direction = 1
infeasible_event.terminal = True

# %%
start_time = time.time()

ts = np.linspace(0, 15, 100)  # Desired integration resolution and interval
y0 = [0.1, 10]

with tqdm() as pbar:
    dynamic_system.pbar = pbar

    sol = solve_ivp(
        fun=dynamic_system,
        events=[infeasible_event],
        t_span=(ts.min(), ts.max()),
        y0=y0,
        t_eval=ts,
        rtol=1e-6,
        atol=1e-8,
        method='BDF'
    )
    
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# t = 0.045: : 231it [1:00:27, 14.31s/it]

# %%
sol

# %%
model_HMR.reactions.E_3118
# Out:
# /home/csiharath/.local/lib/python3.8/site-packages/cobra/core/dictlist.py:214: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if current_length is 0:
# /home/csiharath/.local/lib/python3.8/site-packages/cobra/core/dictlist.py:214: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if current_length is 0:
# /home/csiharath/.local/lib/python3.8/site-packages/cobra/core/dictlist.py:214: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if current_length is 0:
# /home/csiharath/.local/lib/python3.8/site-packages/cobra/core/dictlist.py:214: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   if current_length is 0:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/cobra/core/dictlist.py:452, in DictList.__getattr__(self, attr)
#     451 try:
# --> 452     return DictList.get_by_id(self, attr)
# ...
